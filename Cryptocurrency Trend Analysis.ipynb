# %% [markdown]
# # Data Preparation

# %% [markdown]
#     Team Members:  Ojasvi Maleyvar
#                    Anmol Shah
#                    Priyanka Chandore
#                    Shivangi M Gupta

# %%
import numpy as np
import pandas as pd
import os
#from sklearn import linear_model

# t = os.path.isfile('/Users/oj/Desktop/PythonProjectCrypto/CryptoData/ethereum_price-Copy1.csv')
# if t:
btc = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/bitcoin_price.csv')
eth = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/ethereum_price.csv')
ripple = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/ripple_price.csv')
monero = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/monero_price.csv')
dash = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/dash_price.csv')
litecoin = pd.read_csv('/Users/shivangi/Desktop/CIS8005-Final Poject/CryptoData/litecoin_price.csv')
# else:
#     print("File Not found")

    
#eth[:]

# %%
# data = eth.replace(to_replace='-', value=None, inplace=False, limit=None, regex=False, method='ffill')
def req_data(coindb):
    coindb = coindb.loc[:,['Date','Close']] #Only working with Closing values for this study
    coindb['Date'] = pd.to_datetime(coindb['Date'])
    #coindb = coindb.set_index(['Date'])  #to be verified with Anmol for linear regression function
    return coindb
# indexed_df = btc_req_data.set_index(['Date'])       
btc_req_data = pd.DataFrame(req_data(btc))
eth_req_data = pd.DataFrame(req_data(eth))
ripple_req_data = pd.DataFrame(req_data(ripple))
monero_req_data = pd.DataFrame(req_data(monero))
dash_req_data = pd.DataFrame(req_data(dash))
litecoin_req_data = pd.DataFrame(req_data(litecoin))

btc_req_data
#eth_req_data
#ripple_req_data
#monero_req_data
#dash_req_data
#litecoin_req_data


# data = eth.replace(to_replace='-',value=np.NaN, method='ffill')
# #data
# #
# data.fillna(method='ffill')
# data
# Out:
#            Date    Close
# 0    2017-09-17  3582.88
# 1    2017-09-16  3625.04
# 2    2017-09-15  3637.52
# 3    2017-09-14  3154.95
# 4    2017-09-13  3882.59
# 5    2017-09-12  4130.81
# 6    2017-09-11  4161.27
# 7    2017-09-10  4122.94
# 8    2017-09-09  4226.06
# 9    2017-09-08  4228.75
# 10   2017-09-07  4599.88
# 11   2017-09-06  4597.12
# 12   2017-09-05  4376.53
# 13   2017-09-04  4236.31
# 14   2017-09-03  4582.96
# 15   2017-09-02  4578.77
# 16   2017-09-01  4892.01
# 17   2017-08-31  4703.39
# 18   2017-08-30  4565.30
# 19   2017-08-29  4579.02
# 20   2017-08-28  4382.66
# 21   2017-08-27  4382.88
# 22   2017-08-26  4352.40
# 23   2017-08-25  4371.60
# 24   2017-08-24  4334.68
# 25   2017-08-23  4151.52
# 26   2017-08-22  4100.52
# 27   2017-08-21  4001.74
# 28   2017-08-20  4087.66
# 29   2017-08-19  4193.70
# ...         ...      ...
# 1574 2013-05-27   129.75
# 1575 2013-05-26   133.48
# 1576 2013-05-25   131.98
# 1577 2013-05-24   133.20
# 1578 2013-05-23   126.70
# ...

# %% [markdown]
# # Exploration/Plotting

# %%
# Historical prices 
import matplotlib.pyplot as plt

def plot_data(coindb, name):
    #plt.subplots(6, figsize=(16,6))
    plt.figure(figsize=(16,6))
    x = coindb['Date'] #coindb.index
    y = coindb['Close']
    #lst = coindb.Date.iloc[:]
    #print(coindb)
    plt.xlabel('Timeline')
    plt.ylabel(name)                    
    plt.plot(x,y,'--')
#     plt.xticks(coindb.Date.iloc[0], coindb.Date.iloc[-1])
    _ = plt.xticks(rotation=45)
#     plt.axis(coindb.Date.iloc[0], coindb.Date.iloc[-1])
    plt.show()

#print(btc_req_data.Date.iloc[0])
#print(btc_req_data.Date.iloc[-1])
plot_data(btc_req_data, 'Bitcoin Closing Values')
plot_data(eth_req_data, 'Ethereum Closing Values')
plot_data(ripple_req_data, 'Ripple Closing Values')
plot_data(monero_req_data, 'Monero Closing Values')
plot_data(dash_req_data, 'Dash Closing Values')
plot_data(litecoin_req_data, 'Litecoin Closing Values')

# %% [markdown]
# OBSERVATIONS:
#     1. For the given time frame, it is observed that there has been a sudden surge in
#     the closing prices of the cryptocurrencies

# %%
# New_dataSet = btc_req_data.merge(eth_req_data, how='inner', on= btc_req_data.index, left_index=True, right_index=True)
# New_dataSet 

#Above: merging - not working

# df1.merge(df2,on='name').merge(df3,on='name') ---- how to concatenate multiple dframes with chaining

# import seaborn as sns
New_dataSet = pd.DataFrame()
#New_dataSet['Date'] = btc_req_data['Date']
New_dataSet['Bitcoin Closing Price'] = btc_req_data['Close']
New_dataSet['Ethereum Closing Price'] = eth_req_data['Close']
New_dataSet['Ripple Closing Price'] = ripple_req_data['Close']
New_dataSet['Monero Closing Price'] = monero_req_data['Close']
New_dataSet['Dash Closing Price'] = dash_req_data['Close']
New_dataSet['Litecoin Closing Price'] = litecoin_req_data['Close']
#New_dataSet
New_dataSet.fillna(0, inplace=True)
New_dataSet
# Out:
#       Bitcoin Closing Price  Ethereum Closing Price  Ripple Closing Price  \
# 0                   3582.88                  251.75              0.178393
# 1                   3625.04                  246.52              0.179082
# 2                   3637.52                  250.46              0.181358
# 3                   3154.95                  213.91              0.164167
# 4                   3882.59                  277.11              0.200778
# 5                   4130.81                  291.46              0.209303
# 6                   4161.27                  294.53              0.214441
# 7                   4122.94                  288.75              0.213031
# 8                   4226.06                  294.40              0.209995
# 9                   4228.75                  296.50              0.211518
# 10                  4599.88                  329.43              0.223640
# 11                  4597.12                  334.34              0.226186
# ...

# %%
# New_dataSet.plot()
# New_dataSet
New_dataSet = New_dataSet.iloc[::-1]
# figure()
mx = New_dataSet.plot(figsize=(20,16))
mx.set_xlabel("Time")
mx.set_ylabel("Closing Prices")



# plt.figure(figsize=(20,16))
# plt.xlabel('Dates')
# plt.ylabel('Closing Values')
# plt.plot(range(len(New_dataSet)), New_dataSet['Bitcoin Closing Price'], '--')
# plt.plot(range(len(New_dataSet)), New_dataSet['Ethereum Closing Price'], ':')
# plt.plot(range(len(New_dataSet)), New_dataSet['Ripple Closing Price'], '--')
# plt.plot(range(len(New_dataSet)), New_dataSet['Monero Closing Price'], ':')
# plt.plot(range(len(New_dataSet)), New_dataSet['Dash Closing Price'], '--')
# plt.plot(range(len(New_dataSet)), New_dataSet['Litecoin Closing Price'], ':')
# plt.legend(['Bitcoin', 'Ethereum','Ripple','Monero','Dash','Litecoin'], loc=2)
plt.show()

# %% [raw]
# # NORMALIZED PLOT

# %%
# df.loc[:, 'quantity'] = df['quantity'] * -1
Norm_New_dataSet = pd.DataFrame()#New_dataSet.iloc[::-1]
Norm_New_dataSet
Norm_New_dataSet['Norm Bitcoin Closing Price'] = New_dataSet['Bitcoin Closing Price']/New_dataSet['Bitcoin Closing Price'].mean()
Norm_New_dataSet['Norm Ethereum Closing Price'] = New_dataSet['Ethereum Closing Price']/New_dataSet['Ethereum Closing Price'].mean()
Norm_New_dataSet['Norm Ripple Closing Price'] = New_dataSet['Ripple Closing Price']/New_dataSet['Ripple Closing Price'].mean()
Norm_New_dataSet['Norm Monero Closing Price'] = New_dataSet['Monero Closing Price']/New_dataSet['Monero Closing Price'].mean()
Norm_New_dataSet['Norm Dash Closing Price'] = New_dataSet['Dash Closing Price']/New_dataSet['Dash Closing Price'].mean()
Norm_New_dataSet['Norm Litecoin Closing Price'] = New_dataSet['Litecoin Closing Price']/New_dataSet['Litecoin Closing Price'].mean()
#New_dataSet
# New_dataSet.fillna(0, inplace=True)
# New_dataSet
Norm_New_dataSet = Norm_New_dataSet[::-1]
Norm_New_dataSet
# Out:
#       Norm Bitcoin Closing Price  Norm Ethereum Closing Price  \
# 0                       5.224473                     9.698012
# 1                       5.285950                     9.496540
# 2                       5.304148                     9.648319
# 3                       4.600476                     8.240325
# 4                       5.661504                    10.674940
# 5                       6.023452                    11.227737
# 6                       6.067869                    11.346000
# 7                       6.011977                    11.123341
# 8                       6.162344                    11.340992
# 9                       6.166266                    11.421890
# 10                      6.707440                    12.690432
# 11                      6.703415                    12.879577
# 12                      6.381756                    12.057124
# 13                      6.177290                    11.370655
# ...

# %%
# plt.xlabel('Time')
# plt.ylabel('Normalized Closing Values')
ax = Norm_New_dataSet[::-1].plot(figsize=(20,16))
ax.set_xlabel("Time")
ax.set_ylabel("Normalized Closing values")
plt.show()

# %% [markdown]
# # Stability Check

# %%
import statistics
lst=[]
coindbdict = {'Bitcoin': btc_req_data, 'Ethereum': eth_req_data, 'Ripple': ripple_req_data, 'Monero':monero_req_data,'Dash':dash_req_data,'Litecoin':litecoin_req_data}
# coindblst = [btc_req_data,eth_req_data,ripple_req_data,monero_req_data,dash_req_data,litecoin_req_data]
# print(coindblst)
# print(coindbdict['Bitcoin'])

# for key in coindbdict:
#     lst.append()
def Var_Coeff(coindb, name):
        mean = coindb['Close'].mean()
        #print(mean)
        std_dev = statistics.stdev(coindb['Close'])
        coeff_var = round((std_dev/mean),5)
        return coeff_var, name

for key in coindbdict:
    lst.append(Var_Coeff(coindbdict[key], key))
lst.sort()

# print(lst)
print("Most Stable coin / Least volatile crypto-currency, for the given dataset is:",min(lst)[1].upper(),"with a variance coeff of",min(lst)[0])
print("Least Stable coin / Most volatile crypto-currency, for the given dataset is:",max(lst)[1].upper(),"with a variance coeff of",max(lst)[0])

# for coin in coindblst:
#     lst.append(Var_Coeff(coin))

#lst.append()

# btc_var = Var_Coeff(btc_req_data, 'Bitcoin Variance')
# eth = Var_Coeff(eth_req_data, 'Ethereum Variance')
# ripple = Var_Coeff(ripple_req_data, 'Ripple Variance')
# monero = Var_Coeff(monero_req_data, 'Monero Variance')
# dash = Var_Coeff(dash_req_data, 'Dash Variance')
# litecoin_var = Var_Coeff(litecoin_req_data, 'Litecoin Variance')
# Out:
# Most Stable coin / Least volatile crypto-currency, for the given dataset is: BITCOIN with a variance coeff of 1.14076
# Least Stable coin / Most volatile crypto-currency, for the given dataset is: DASH with a variance coeff of 2.24313

# %% [markdown]
# # Correlation

# %%
# index = btc_req_data['Date']
# columns = [btc_req_data['Close'],eth_req_data['Close'],ripple_req_data['Close'],monero_req_data['Close'],dash_req_data['Close'],litecoin_req_data['Close']]
# df = pd.DataFrame(index = index, columns=columns)
# #df['BTC']= btc_req_data['Close']
# print(df)

# import seaborn as sns

New_dataSet_Corr = pd.DataFrame()
New_dataSet_Corr['Bitcoin Closing Price'] = btc_req_data['Close']
New_dataSet_Corr['Ethereum Closing Price'] = eth_req_data['Close']
New_dataSet_Corr['Ripple Closing Price'] = ripple_req_data['Close']
New_dataSet_Corr['Monero Closing Price'] = monero_req_data['Close']
New_dataSet_Corr['Dash Closing Price'] = dash_req_data['Close']
New_dataSet_Corr['Litecoin Closing Price'] = litecoin_req_data['Close']
#New_dataSet
New_dataSet_Corr.fillna(0, inplace=True)

x = New_dataSet_Corr.pct_change().corr(method='pearson')
x
# sns.heatmap(x,
#            xticklables=x.columns.values,
#            yticklables=x.columns.values)
# Out:
#                         Bitcoin Closing Price  Ethereum Closing Price  \
# Bitcoin Closing Price                1.000000                0.213053
# Ethereum Closing Price               0.213053                1.000000
# Ripple Closing Price                 0.321753                0.051813
# Monero Closing Price                 0.374451                0.191895
# Dash Closing Price                   0.373705                0.160224
# Litecoin Closing Price               0.666596                0.176788
#
#                         Ripple Closing Price  Monero Closing Price  \
# Bitcoin Closing Price               0.321753              0.374451
# Ethereum Closing Price              0.051813              0.191895
# Ripple Closing Price                1.000000              0.017415
# Monero Closing Price                0.017415              1.000000
# Dash Closing Price                  0.076917              0.310150
# Litecoin Closing Price              0.281097              0.254751
#
# ...

# %%
plt.subplots(figsize=(10,10))
plt.xticks(range(6), x.columns.values, rotation='vertical')
plt.yticks(range(6), x.columns.values)
plt.xlabel('CryptoCurrency Correlation')
heat = plt.imshow(x, cmap="hot")#, figsize=(20,16))
plt.colorbar(heat)

plt.show()

# %% [markdown]
# # Regression models & Prediction

# %% [markdown]
# Linear Regression
# Criterion variable --> Close Price
# Predictor Variable --> Date

# %% [markdown]
# Divided our dataframe into Test & Train data frame which is further used in the model.

# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd



def TestData(coindb):
    m=(len(coindb)//10)*9
    n=len(coindb)//9
    coindb_test=coindb.iloc[m:len(coindb)]
    coindb_train=coindb.iloc[0:m]
    print(m,n)
    df_train = pd.DataFrame({ 'A' : range(0, m,1)})
    df_test = pd.DataFrame({ 'B' : range(m, len(coindb) ,1)})
#     print(df_train)
#     print(df_test)
#     print(coindb_train)
#     print(coindb_test)
    return coindb_test,coindb_train,df_test,df_train

#index_train = pd.Index(np.arange(m))
    #print(it)
    #index_test = pd.Index(np.arange(m,m+n))
    #values_train =pd.DataFrame()
    #print(index_train)
    #print(index_test)
    #m, n
#TestData(btc_req_data)
# print(len(btc_req_data))
# values_train =pd.DataFrame[0,len(btc_req_data)//4]
# print(values_train)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
def linear_reg(df):
    df = df[::-1]
    test,train,i_test,i_train=TestData(df)
    
    regr = linear_model.LinearRegression()
    
    X = i_train['A'].values[:,np.newaxis]
    x_test=test['Close'].values[:,np.newaxis]
    y_test=i_test['B'].values[:,np.newaxis]
    # Train the model using the training sets
    Y=train['Close'].values[:,np.newaxis]
    # Make predictions using the testing set
    #y = regr.predict(test['Close'].values.reshape(-1,1))
    # target data is array of shape (n,) 
#     print(X)
#     print(Y)
    model2 = LinearRegression()
    model2.fit(X, Y)

    plt.plot(X, Y,color='g')
    plt.show()
    #trend= model2.predict(np.arange(350).reshape(-1,1))
    #plt.plot(trend,label='trend')
    #plt.show()
    plt.plot(y_test, model2.predict(x_test),color='k')
    print("Predicted first 5 values :")
    print(model2.predict(x_test)[:5])

    plt.show()
    
    #plt.scatter(test['Close'], i_test['B'],  color='black')
    #plt.plot(test, y, color='blue', linewidth=3)

    #plt.xticks(())
    #plt.yticks(())

    #plt.show()
#     ols = linear_model.LinearRegression()
#     model = ols.fit(i_train, y_train)
#     h_trend = model.predict(i_test)[:]
#     plt.plot(h_trend)
#     plt.show()
    
print("Bitcoin Prediction")
linear_reg(btc_req_data)
print("Ethereum Prediction")
linear_reg(eth_req_data)
print("Ripple Prediction")
linear_reg(ripple_req_data)
print("Monero Prediction")
linear_reg(monero_req_data)
print("Dash Prediction")
linear_reg(dash_req_data)
print("Litecoin Prediction")
linear_reg(litecoin_req_data)
          
#df.head() # prodce a header from the first data row


# LinearRegression will expect an array of shape (n, 1) 
# for the "Training data"
# Out:
# Bitcoin Prediction
# 1440 178
# Predicted first 5 values :
# [[ 604.2603602 ]
#  [ 603.96261195]
#  [ 607.69856903]
#  [ 607.46663881]
#  [ 613.07057443]]
# Ethereum Prediction
# 693 85
# Predicted first 5 values :
# [[ 19.63722024]
#  [ 15.97753269]
#  [ 18.38910829]
#  [ 17.47238538]
#  [ 15.74339914]]
# Ripple Prediction
# 1350 167
# Predicted first 5 values :
# [[ 0.01178498]
#  [ 0.01178498]
#  [ 0.01178498]
#  [ 0.01178498]
#  [ 0.011785  ]]
# Monero Prediction
# 1089 135
# Predicted first 5 values :
# [[-2.70438026]
#  [-2.72383899]
#  [-2.71531785]
#  [-2.67207621]
#  [-2.6524903 ]]
# Dash Prediction
# 1179 145
# Predicted first 5 values :
# [[-3.58546924]
#  [-3.79605519]
#  [-3.84411198]
#  [-3.84357202]
#  [-3.97154348]]
# Litecoin Prediction
# 1440 178
# Predicted first 5 values :
# [[ 8.86512783]
#  [ 8.86258168]
#  [ 8.86818321]
#  [ 8.86721104]
#  [ 8.8675351 ]]

# %% [markdown]
# Future value prediction can be done using Multivariate Regression or Polynomial Regression model.
